# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('3DES_performance.csv')

# make new file name based on File Type Column
df['File Type'] = df['File Type'].str.replace('.', '')
# make a new file for each file type
for file_type in df['File Type'].unique():
    df[df['File Type'] == file_type].to_csv('3DES_performance_analysis_' + file_type + '.csv', index=False)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_18888\4179041446.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['File Type'] = df['File Type'].str.replace('.', '')

# %%
df = pd.read_csv('3DES_performance_analysis_txt.csv')
sns.pairplot(df)
plt.suptitle('Text Files')
summary_txt = df.describe()
# print(summary)
print(summary_txt.loc[["mean","std","min","max"]])
# Out:
#          File Size  Encryption Time  Decryption Time
# mean  5.013421e+06       235.330899       231.429627
# std   2.932423e+06       138.451477       136.359323
# min   1.006600e+04         1.093149         0.514507
# max   1.001704e+07       511.963844       539.636850

# %%
df = pd.read_csv('3DES_performance_analysis_mp3.csv')
sns.pairplot(df)
plt.suptitle('MP3 Files')
summary_mp3 = df.describe()
# print(summary)

print(summary_mp3.loc[["mean","std","min","max"]])
# type(summary)
# Out:
#           File Size  Encryption Time  Decryption Time
# mean  146745.690000        11.418571        11.196361
# std    66352.082649         6.004129         6.122250
# min    43702.000000         0.000000         0.000000
# max   255628.000000        26.497126        23.614645

# %%
df = pd.read_csv('3DES_performance_analysis_mp4.csv')
sns.pairplot(df)
plt.suptitle('MP4 Files')
summary_mp4 = df.describe()
# print(summary)
print(summary_mp4.loc[["mean","std","min","max"]])
# Out:
#         File Size  Encryption Time  Decryption Time
# mean  31817.06000         2.040417         2.050908
# std   13445.50845         2.463244         2.417319
# min   11028.00000         0.000000         0.000000
# max   54705.00000         9.332180        10.217905

# %%
df = pd.read_csv('3DES_performance_analysis_png.csv')
sns.pairplot(df)
plt.suptitle('PNG Files')
summary_png = df.describe()
# print(summary)
print(summary_png.loc[["mean","std","min","max"]])
# Out:
#         File Size  Encryption Time  Decryption Time
# mean  2446.380000         0.306404         0.114105
# std   1060.720679         0.763241         0.318631
# min    761.000000         0.000000         0.000000
# max   4923.000000         6.603241         1.142263

# %%
summary_mp3['File Type'] = 'mp3'
summary_mp4['File Type'] = 'mp4'
summary_png['File Type'] = 'png'
summary_txt['File Type'] = 'txt'
print(summary_mp3)
# Out:
#            File Size  Encryption Time  Decryption Time File Type
# count     100.000000       100.000000       100.000000       mp3
# mean   146745.690000        11.418571        11.196361       mp3
# std     66352.082649         6.004129         6.122250       mp3
# min     43702.000000         0.000000         0.000000       mp3
# 25%     94655.500000         6.724834         6.306291       mp3
# 50%    143230.500000        10.435224         9.922028       mp3
# 75%    205687.750000        16.076744        15.653908       mp3
# max    255628.000000        26.497126        23.614645       mp3

# %%
df_final = pd.concat([summary_txt, summary_mp3, summary_mp4, summary_png])
df_final
# Out:
#           File Size  Encryption Time  Decryption Time File Type
# count  1.000000e+02       100.000000       100.000000       txt
# mean   5.013421e+06       235.330899       231.429627       txt
# std    2.932423e+06       138.451477       136.359323       txt
# min    1.006600e+04         1.093149         0.514507       txt
# 25%    2.511710e+06       112.402320       118.490219       txt
# 50%    5.013400e+06       226.896286       235.019803       txt
# 75%    7.515210e+06       350.211084       333.893239       txt
# max    1.001704e+07       511.963844       539.636850       txt
# count  1.000000e+02       100.000000       100.000000       mp3
# mean   1.467457e+05        11.418571        11.196361       mp3
# std    6.635208e+04         6.004129         6.122250       mp3
# min    4.370200e+04         0.000000         0.000000       mp3
# 25%    9.465550e+04         6.724834         6.306291       mp3
# 50%    1.432305e+05        10.435224         9.922028       mp3
# 75%    2.056878e+05        16.076744        15.653908       mp3
# max    2.556280e+05        26.497126        23.614645       mp3
# count  1.000000e+02       100.000000       100.000000       mp4
# mean   3.181706e+04         2.040417         2.050908       mp4
# std    1.344551e+04         2.463244         2.417319       mp4
# min    1.102800e+04         0.000000         0.000000       mp4
# 25%    1.938475e+04         0.000000         0.000000       mp4
# 50%    3.247950e+04         0.998855         1.325011       mp4
# 75%    4.390525e+04         2.983809         2.954721       mp4
# max    5.470500e+04         9.332180        10.217905       mp4
# count  1.000000e+02       100.000000       100.000000       png
# mean   2.446380e+03         0.306404         0.114105       png
# std    1.060721e+03         0.763241         0.318631       png
# min    7.610000e+02         0.000000         0.000000       png
# 25%    1.627750e+03         0.000000         0.000000       png
# 50%    2.237500e+03         0.000000         0.000000       png
# 75%    3.226500e+03         0.493824         0.000000       png
# max    4.923000e+03         6.603241         1.142263       png

# %%
df_final['Statistics'] = ['Count', 'Mean', 'Std Dev', 'Min', '25%', 'Median', '75%', 'Max'] * 4
df_final = df_final.set_index(['File Type', 'Statistics'])
df_final
# Out:
#                          File Size  Encryption Time  Decryption Time
# File Type Statistics
# txt       Count       1.000000e+02       100.000000       100.000000
#           Mean        5.013421e+06       235.330899       231.429627
#           Std Dev     2.932423e+06       138.451477       136.359323
#           Min         1.006600e+04         1.093149         0.514507
#           25%         2.511710e+06       112.402320       118.490219
#           Median      5.013400e+06       226.896286       235.019803
#           75%         7.515210e+06       350.211084       333.893239
#           Max         1.001704e+07       511.963844       539.636850
# mp3       Count       1.000000e+02       100.000000       100.000000
#           Mean        1.467457e+05        11.418571        11.196361
#           Std Dev     6.635208e+04         6.004129         6.122250
#           Min         4.370200e+04         0.000000         0.000000
#           25%         9.465550e+04         6.724834         6.306291
#           Median      1.432305e+05        10.435224         9.922028
#           75%         2.056878e+05        16.076744        15.653908
#           Max         2.556280e+05        26.497126        23.614645
# mp4       Count       1.000000e+02       100.000000       100.000000
#           Mean        3.181706e+04         2.040417         2.050908
#           Std Dev     1.344551e+04         2.463244         2.417319
#           Min         1.102800e+04         0.000000         0.000000
#           25%         1.938475e+04         0.000000         0.000000
#           Median      3.247950e+04         0.998855         1.325011
#           75%         4.390525e+04         2.983809         2.954721
#           Max         5.470500e+04         9.332180        10.217905
# png       Count       1.000000e+02       100.000000       100.000000
#           Mean        2.446380e+03         0.306404         0.114105
#           Std Dev     1.060721e+03         0.763241         0.318631
#           Min         7.610000e+02         0.000000         0.000000
#           25%         1.627750e+03         0.000000         0.000000
#           Median      2.237500e+03         0.000000         0.000000
#           75%         3.226500e+03         0.493824         0.000000
#           Max         4.923000e+03         6.603241         1.142263

# %%
df_final.loc[[('txt', 'Mean'),('mp3', 'Mean'),('mp4', 'Mean'),('png', 'Mean')]]
# Out:
#                        File Size  Encryption Time  Decryption Time
# File Type Statistics
# txt       Mean        5013420.88       235.330899       231.429627
# mp3       Mean         146745.69        11.418571        11.196361
# mp4       Mean          31817.06         2.040417         2.050908
# png       Mean           2446.38         0.306404         0.114105
