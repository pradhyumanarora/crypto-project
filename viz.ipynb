# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('AES_performance_analysis1.csv')

# make new file name based on File Type Column
df['File Type'] = df['File Type'].str.replace('.', '')
# make a new file for each file type
for file_type in df['File Type'].unique():
    df[df['File Type'] == file_type].to_csv('AES_performance_analysis_' + file_type + '.csv', index=False)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_13628\4117259823.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['File Type'] = df['File Type'].str.replace('.', '')

# %%
df = pd.read_csv('AES_performance_analysis_txt.csv')
sns.pairplot(df)
plt.suptitle('Text Files')



df = pd.read_csv('AES_performance_analysis_mp3.csv')
sns.pairplot(df)
plt.suptitle('MP3 Files')

df = pd.read_csv('AES_performance_analysis_mp4.csv')
sns.pairplot(df)
plt.suptitle('MP4 Files')

df = pd.read_csv('AES_performance_analysis_png.csv')
sns.pairplot(df)
plt.suptitle('PNG Files')
# Out:
# Text(0.5, 0.98, 'PNG Files')

# %%
summary = df.describe()
print(summary)
# Out:
#           File Size  Encryption Time(ms)  Decryption Time(ms)
# count  1.000000e+02           100.000000           100.000000
# mean   5.013421e+06            34.098165            39.038532
# std    2.932423e+06            21.736349            25.697128
# min    1.006600e+04             0.000000             0.000000
# 25%    2.511710e+06            14.740467            15.001595
# 50%    5.013400e+06            33.487082            37.007689
# 75%    7.515210e+06            52.816570            57.002783
# max    1.001704e+07            97.995281           116.004944

# %%
df.boxplot(column=['Encryption Time(ms)', 'Decryption Time(ms)'])
plt.show()

# %%
summary.plot(kind='bar')
plt.show()

# %%
sns.heatmap(df.corr())
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("./3des/AES_performance_analysis.csv")

# Create a line graph for the first column
plt.plot(df.index, df["Encryption Time(ms)"], label="Column 1")

# Create a line graph for the second column
plt.plot(df.index, df["Decryption Time(ms)"], label="Column 2")

# Add a title and axis labels
plt.title("Line Graph")
plt.xlabel("Index")
plt.ylabel("Value")

# Add a legend
plt.legend()

# Show the graph
plt.show()

# %% [markdown]
# visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("AES_performance_analysis1.csv")

# Create a line graph for the first column
plt.plot(df.index, df["Encryption Time(ms)"], label="Column 1")

# Create a line graph for the second column
plt.plot(df.index, df["Decryption Time(ms)"], label="Column 2")

# Add a title and axis labels
plt.title("Line Graph")
plt.xlabel("Index")
plt.ylabel("Value")

# Add a legend
plt.legend()

# Show the graph
plt.show()

# %% [markdown]
# Clearing Data

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
df = pd.read_csv('AES_performance_analysis.csv')

# Filter out rows with a file type of 'enc'
df = df[df['File Type'] != '.enc']

# Save the filtered DataFrame to a new Excel file
df.to_csv('new_filename.csv', index=False)

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
df = pd.read_csv('new_filename.csv')

# Filter out rows with a file type of 'enc'
df = df[df['File Type'] != '.dec']

# Save the filtered DataFrame to a new Excel file
df.to_csv('new_filename1.csv', index=False)

# %% [markdown]
# Final BlowFish

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('Blowfish_performance.csv')

# make new file name based on File Type Column
df['File Type'] = df['File Type'].str.replace('.', '')
# make a new file for each file type
for file_type in df['File Type'].unique():
    df[df['File Type'] == file_type].to_csv('Blowfish_performance_analysis_' + file_type + '.csv', index=False)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_20756\3240277513.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['File Type'] = df['File Type'].str.replace('.', '')

# %%
df = pd.read_csv('Blowfish_performance_analysis_txt.csv')
sns.pairplot(df)
plt.suptitle('Text Files')
summary_txt = df.describe()
# print(summary)
print(summary_txt.loc[["mean","std","min","max"]])
# Out:
#          File Size  Encryption Time  Decryption Time
# mean  5.013421e+06         0.069173         0.075337
# std   2.932423e+06         0.038439         0.045854
# min   1.006600e+04         0.001202         0.002990
# max   1.001704e+07         0.154165         0.211311

# %%
df = pd.read_csv('Blowfish_performance_analysis_mp3.csv')
sns.pairplot(df)
plt.suptitle('MP3 Files')
summary_mp3 = df.describe()
# print(summary)

print(summary_mp3.loc[["mean","std","min","max"]])
# type(summary)
# Out:
#           File Size  Encryption Time  Decryption Time
# mean  146745.690000         0.008684         0.013062
# std    66352.082649         0.004869         0.008079
# min    43702.000000         0.000993         0.001872
# max   255628.000000         0.022096         0.065541

# %%
df = pd.read_csv('Blowfish_performance_analysis_mp4.csv')
sns.pairplot(df)
plt.suptitle('MP4 Files')
summary_mp4 = df.describe()
# print(summary)
print(summary_mp4.loc[["mean","std","min","max"]])
# Out:
#         File Size  Encryption Time  Decryption Time
# mean  31817.06000         0.005364         0.008768
# std   13445.50845         0.003376         0.004123
# min   11028.00000         0.000000         0.000997
# max   54705.00000         0.015751         0.024709

# %%
df = pd.read_csv('Blowfish_performance_analysis_png.csv')
sns.pairplot(df)
plt.suptitle('PNG Files')
summary_png = df.describe()
# print(summary)
print(summary_png.loc[["mean","std","min","max"]])
# Out:
#         File Size  Encryption Time  Decryption Time
# mean  2446.380000         0.004796         0.007932
# std   1060.720679         0.003722         0.021172
# min    761.000000         0.000622         0.000000
# max   4923.000000         0.020781         0.214871

# %%
summary_mp3['File Type'] = 'mp3'
summary_mp4['File Type'] = 'mp4'
summary_png['File Type'] = 'png'
summary_txt['File Type'] = 'txt'
print(summary_mp3)
# Out:
#            File Size  Encryption Time  Decryption Time File Type
# count     100.000000       100.000000       100.000000       mp3
# mean   146745.690000         0.008684         0.013062       mp3
# std     66352.082649         0.004869         0.008079       mp3
# min     43702.000000         0.000993         0.001872       mp3
# 25%     94655.500000         0.004927         0.008320       mp3
# 50%    143230.500000         0.008863         0.011251       mp3
# 75%    205687.750000         0.011946         0.016436       mp3
# max    255628.000000         0.022096         0.065541       mp3

# %%
sum_final = pd.concat([summary_txt, summary_mp3, summary_mp4, summary_png])
sum_final
# Out:
#           File Size  Encryption Time  Decryption Time File Type
# count  1.000000e+02       100.000000       100.000000       txt
# mean   5.013421e+06         0.069173         0.075337       txt
# std    2.932423e+06         0.038439         0.045854       txt
# min    1.006600e+04         0.001202         0.002990       txt
# 25%    2.511710e+06         0.035042         0.038752       txt
# 50%    5.013400e+06         0.068487         0.067914       txt
# 75%    7.515210e+06         0.097494         0.100427       txt
# max    1.001704e+07         0.154165         0.211311       txt
# count  1.000000e+02       100.000000       100.000000       mp3
# mean   1.467457e+05         0.008684         0.013062       mp3
# std    6.635208e+04         0.004869         0.008079       mp3
# min    4.370200e+04         0.000993         0.001872       mp3
# 25%    9.465550e+04         0.004927         0.008320       mp3
# 50%    1.432305e+05         0.008863         0.011251       mp3
# 75%    2.056878e+05         0.011946         0.016436       mp3
# max    2.556280e+05         0.022096         0.065541       mp3
# count  1.000000e+02       100.000000       100.000000       mp4
# mean   3.181706e+04         0.005364         0.008768       mp4
# std    1.344551e+04         0.003376         0.004123       mp4
# min    1.102800e+04         0.000000         0.000997       mp4
# 25%    1.938475e+04         0.001993         0.006489       mp4
# 50%    3.247950e+04         0.005597         0.008668       mp4
# 75%    4.390525e+04         0.007846         0.010930       mp4
# max    5.470500e+04         0.015751         0.024709       mp4
# count  1.000000e+02       100.000000       100.000000       png
# mean   2.446380e+03         0.004796         0.007932       png
# std    1.060721e+03         0.003722         0.021172       png
# min    7.610000e+02         0.000622         0.000000       png
# 25%    1.627750e+03         0.001985         0.003974       png
# 50%    2.237500e+03         0.004984         0.005675       png
# 75%    3.226500e+03         0.006973         0.007127       png
# max    4.923000e+03         0.020781         0.214871       png

# %%
sum_final['Statistics'] = ['Count', 'Mean', 'Std Dev', 'Min', '25%', 'Median', '75%', 'Max'] * 4

# %%
sum_final = sum_final.set_index(['File Type', 'Statistics'])

# %%
sum_final
# Out:
#                          File Size  Encryption Time  Decryption Time
# File Type Statistics
# txt       Count       1.000000e+02       100.000000       100.000000
#           Mean        5.013421e+06         0.069173         0.075337
#           Std Dev     2.932423e+06         0.038439         0.045854
#           Min         1.006600e+04         0.001202         0.002990
#           25%         2.511710e+06         0.035042         0.038752
#           Median      5.013400e+06         0.068487         0.067914
#           75%         7.515210e+06         0.097494         0.100427
#           Max         1.001704e+07         0.154165         0.211311
# mp3       Count       1.000000e+02       100.000000       100.000000
#           Mean        1.467457e+05         0.008684         0.013062
#           Std Dev     6.635208e+04         0.004869         0.008079
#           Min         4.370200e+04         0.000993         0.001872
#           25%         9.465550e+04         0.004927         0.008320
#           Median      1.432305e+05         0.008863         0.011251
#           75%         2.056878e+05         0.011946         0.016436
#           Max         2.556280e+05         0.022096         0.065541
# mp4       Count       1.000000e+02       100.000000       100.000000
#           Mean        3.181706e+04         0.005364         0.008768
#           Std Dev     1.344551e+04         0.003376         0.004123
#           Min         1.102800e+04         0.000000         0.000997
#           25%         1.938475e+04         0.001993         0.006489
#           Median      3.247950e+04         0.005597         0.008668
#           75%         4.390525e+04         0.007846         0.010930
#           Max         5.470500e+04         0.015751         0.024709
# png       Count       1.000000e+02       100.000000       100.000000
#           Mean        2.446380e+03         0.004796         0.007932
#           Std Dev     1.060721e+03         0.003722         0.021172
#           Min         7.610000e+02         0.000622         0.000000
#           25%         1.627750e+03         0.001985         0.003974
#           Median      2.237500e+03         0.004984         0.005675
#           75%         3.226500e+03         0.006973         0.007127
#           Max         4.923000e+03         0.020781         0.214871

# %%
sum_final.loc[[('txt', 'Mean'),('mp3', 'Mean'),('mp4', 'Mean'),('png', 'Mean')]]
# Out:
#                        File Size  Encryption Time  Decryption Time
# File Type Statistics
# txt       Mean        5013420.88         0.069173         0.075337
# mp3       Mean         146745.69         0.008684         0.013062
# mp4       Mean          31817.06         0.005364         0.008768
# png       Mean           2446.38         0.004796         0.007932
